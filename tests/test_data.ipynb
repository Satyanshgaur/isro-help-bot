# %%
import geopandas as gpd

# Load sample district or river shapefile
gdf = gpd.read_file("/Users/jayant/Documents/isro-help-bot/data/gis_osm_roads_07_1.shp")

# Preview
print(gdf.head())

# Plot the map
gdf.plot()
# Out:
#     osm_id            lastchange  code       fclass geomtype  \
# 0  1863458  2017-05-07T21:36:44Z  5122  residential        W
# 1  2304962  2017-05-08T17:47:35Z  5114    secondary        W
# 2  2304963  2012-10-03T19:50:53Z  5114    secondary        W
# 3  2305016  2017-05-08T17:44:48Z  5113      primary        W
# 4  2305119  2017-04-25T23:11:58Z  5113      primary        W
#
#                          name   ref oneway  maxspeed  layer bridge tunnel  \
# 0                   Rue Julia  None      B         0      0      F      F
# 1  Pont de la Croix de Pierre  None      F        50      0      F      F
# 2     Boulevard des Récollets  None      B        50      0      F      F
# 3           Pont Saint-Michel  None      F        50      1      T      F
# 4                  Boulingrin  None      F        50      0      F      F
#
#                                             geometry
# 0  LINESTRING (1.48447 43.59291, 1.4839 43.59319,...
# ...
