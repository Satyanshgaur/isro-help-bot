# %%
import geopandas as gpd

# Load sample district or river shapefile
gdf = gpd.read_file("/Users/jayant/Documents/isro-help-bot/data/gis_osm_buildings_a_07_1.shp")


# Preview
print(gdf.head())

# Plot the map
gdf.plot()
# Out:
#      osm_id            lastchange  code    fclass geomtype  \
# 0   8074032  2016-11-19T21:26:49Z  1500  building        W
# 1  10360190  2016-01-13T22:35:34Z  1500  building        W
# 2  14687187  2015-05-03T21:20:49Z  1500  building        W
# 3  14804388  2012-03-15T17:58:33Z  1500  building        W
# 4  17027846  2016-09-22T12:28:59Z  1500  building        W
#
#                                name    type  height  levels  \
# 0          Centre Commercial Purpan  retail       0       0
# 1  Parc des Expositions de Toulouse    hall       0       0
# 2                              None    None       0       0
# 3                              None    None       0       0
# 4                         Tripode A    None       0       0
#
#                                             geometry
# 0  POLYGON ((1.3919 43.6096, 1.39206 43.6101, 1.3...
# 1  POLYGON ((1.43346 43.58706, 1.43374 43.58758, ...
# 2  POLYGON ((1.4992 43.54571, 1.49949 43.54586, 1...
# ...
